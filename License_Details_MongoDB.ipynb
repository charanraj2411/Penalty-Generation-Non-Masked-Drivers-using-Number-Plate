# %%
import pymongo

# %%
pip install Flask-PyMongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask_pymongo import PyMongo

# %%
DEFAULT_CONNECTION_URL = "mongodb://localhost:27017/"

DB_NAME = "Charan"

# Establish a connection with mongoDB
client = pymongo.MongoClient(DEFAULT_CONNECTION_URL)

# %%
client.list_database_names()
# Out:
# ['Charan', 'admin', 'config', 'local']

# %%
dataBase = client[DB_NAME]

# %%
COLLECTION_NAME = "License_Details"
collection = dataBase[COLLECTION_NAME]

# %%
record = {
            "Number Plate": "KLG1CA2555",
            "Name": "Leonard Satterfield",
            "Address": "41950 Bailey Passage Suite 534, South Charleschester, NE 41889-5755",
            "License Number": "B82895035"
        }

collection.insert_one(record)

# %%
list_of_records = [
        {
            "Number Plate": "KLG1CA2555",
            "Name": "Leonard Satterfield",
            "Address": "41950 Bailey Passage Suite 534, South Charleschester, NE 41889-5755",
            "License Number": "B82895035"
        },
        {
            "Number Plate": "PGeMN112",
            "Name": "Jamar Zieme",
            "Address": "87397 Lenora Knolls Suite 292, South Abe, SD 66378",
            "License Number": "63506686"
        },
        {
            "Number Plate": "15-LK-10898",
            "Name": "Paris Lehner",
            "Address": "211 Rogelio Hollow Apt. 617, West Jaclyn, IN 03395-2771",
            "License Number": "3543-52-2447"
        },
        {
            "Number Plate": "KAO3NA8385",
            "Name": "Rose Kuhn",
            "Address": "32113 Prohaska Cove Apt. 644, Nienowmouth, TX 35556-7697",
            "License Number": "86209946"
        },
        {
            "Number Plate": "GJW-1-15-A-1138",
            "Name": "Domenick Beatty",
            "Address": "619 Ritchie Prairie, Medhurstton, WI 71537",
            "License Number": "S6967477971028"
        },
        {
            "Number Plate": "NH 14078831:",
            "Name": "Natalia Considine",
            "Address": "57127 Dietrich Lodge Suite 325, West Bethfurt, NE 85733",
            "License Number": " L02145254"
        },
        {
            "Number Plate": "MH15-TC-554",
            "Name": "Wilber Kunze",
            "Address": "926 Stokes Mission, Anabelleburgh, NE 09141-4533",
            "License Number": "A16186409"
        },
        {
            "Number Plate": "THO7BU",
            "Name": "Raul Abernathy",
            "Address": "87234 Funk Coves Apt. 166, North Jillian, MI 63864",
            "License Number": "D 757 809 638 296"
        },
        {
            "Number Plate": "‘DL 12 CG 6648",
            "Name": "Friedrich Zboncak",
            "Address": "16185 Jaskolski Mountains Apt. 679, VonRuedenville, ID 83067-0806",
            "License Number": "LE339708Z"
        },
        {
            "Number Plate": "MH 20 FE 7597.",
            "Name": "Lucy Hauck",
            "Address": "4675 Electa Greens Apt. 060, Mallorytown, CO 47633-1480",
            "License Number": "83-498-7133"
        },
        {
            "Number Plate": "TNT4AL 5074",
            "Name": "Kasandra Hagenes",
            "Address": "573 Schinner Meadows, Rudymouth, GA 31815-8924",
            "License Number": "664575826"
        },
        {
            "Number Plate": "~KLO1AX8000",
            "Name": "Roberta Rau",
            "Address": "431 Ola Square Apt. 833, Prohaskaborough, MA 03454",
            "License Number": " S81269491"
        },
        {
            "Number Plate": "Rie SS ae",
            "Name": "Lisandro Zieme",
            "Address": "7030 Blaze Forges Apt. 972, Kohlermouth, SD 40343-8312",
            "License Number": "37549504"
        },
        {
            "Number Plate": "MHI5-TC-554",
            "Name": "Freida Nader",
            "Address": "974 Nader River, Walterburgh, NC 78661",
            "License Number": "6.47331E+11"
        },
        {
            "Number Plate": "KL55R 2473",
            "Name": "Jamaal Lockman",
            "Address": "806 Gutmann Neck Apt. 981, Swaniawskimouth, CT 68978",
            "License Number": "792850055"
        },
        {
            "Number Plate": "D\r\n\r\nL7S\r\n\r\n\"BS6930\r\n ",
            "Name": "Garret Dickens",
            "Address": "47191 McLaughlin Burgs Suite 178, Bergebury, KY 89420-1159",
            "License Number": "Z49-225-670"
        },
        {
            "Number Plate": "AG °\r\n\r\n01854",
            "Name": "Jimmy Nader",
            "Address": "86990 Jenkins Fords Apt. 976, Braunshire, VA 44050-6175",
            "License Number": "017-93-1253"
        },
        {
            "Number Plate": "TN66U8215.",
            "Name": "Pattie Braun",
            "Address": "306 Klocko Village, East Kirstinbury, MA 79250-5814",
            "License Number": "S28630257"
        },
        {
            "Number Plate": "TN\r\n\r\nj0158\r\n ",
            "Name": "Easton Greenfelder",
            "Address": "Easton Greenfelder68091 King Light Suite 424, New Rashad, VA 39591",
            "License Number": "436-78-3613"
        },
        {
            "Number Plate": "KL 09 ac guos ;",
            "Name": "Kavon Mayer",
            "Address": "58976 Lance Pass, Lake Justen, NC 14911",
            "License Number": "2.5612E+11"
        },
        {
            "Number Plate": "DL2C AG G786",
            "Name": "Garth Lebsack",
            "Address": "57054 Kurt Meadow Suite 115, Anabelleshire, NV 67928-2318",
            "License Number": "3543306102"
        },
        {
            "Number Plate": "/MHO2CT2727]",
            "Name": "Keanu Botsford",
            "Address": "25220 Ramona Islands, Kovacekstad, VA 67091-4163",
            "License Number": "832-38-6596"
        },
        {
            "Number Plate": "'HR 26 BR 9044",
            "Name": "Allene Stoltenberg",
            "Address": "7472 Marvin Glens, Eileenshire, NH 13213-7417",
            "License Number": "07XLT85245"
        },
        {
            "Number Plate": "“HR 99 HA TN) 4575",
            "Name": "Juvenal Schuster",
            "Address": "773 Rodolfo Port, Oranberg, CO 44984-2605",
            "License Number": "99-515-1678"
        },
        {
            "Number Plate": "HR 26 DA 2330",
            "Name": "Annabelle Abbott",
            "Address": "41418 Padberg Neck Apt. 713, West Judd, VA 39648-7510",
            "License Number": "426-04-1974"
        },
        {
            "Number Plate": "KL10AV6633",
            "Name": "Fausto Jacobi",
            "Address": "8925 Dave Squares, Michelstad, ID 82132",
            "License Number": "QB834683F"
        },
        {
            "Number Plate": "HP: SX 4666",
            "Name": "Modesta Miller",
            "Address": "51941 Gerlach Street, West Maye, VA 47448",
            "License Number": "538-25-5585"
        },
        {
            "Number Plate": "KL 1G AV 6342",
            "Name": "Madie Doyle",
            "Address": "853 Virgil Lakes Apt. 532, Adrienport, TX 46094-4654",
            "License Number": "77500197"
        },
        {
            "Number Plate": "6342\r\n\r\nKL 36\r\n\r\nNK\r\n\r\nV",
            "Name": "Abigale Hammes",
            "Address": "419 Romaguera Square, New Karley, MO 18388-8607",
            "License Number": "526290463"
        },
        {
            "Number Plate": "KL 49H\r\n\r\n/5270.",
            "Name": "Eliezer Spencer",
            "Address": "2984 Konopelski Circle Apt. 784, New Blaiseborough, WI 01439-0310",
            "License Number": "T9731081551514"
        },
        {
            "Number Plate": "TN 99F 2378",
            "Name": "Lorna Kris",
            "Address": "917 Kaden Lodge Suite 975, Mosciskistad, MI 47989-4952",
            "License Number": "D 848 388 612 611"
        },
        {
            "Number Plate": "HR 26 CT 6702.",
            "Name": "Jaeden Gutmann",
            "Address": "4812 Orn Mill Apt. 649, South Coychester, MT 67680",
            "License Number": "7.1997E+12"
        },
        {
            "Number Plate": "MH 12DE1433",
            "Name": "Yazmin Keeling",
            "Address": "71971 Dixie Walk Suite 333, North Giovannastad, NM 60509-8195",
            "License Number": "990939401"
        },
        {
            "Number Plate": "| BENS 9239:",
            "Name": "Zack Mayert",
            "Address": "1993 Delpha Shore Apt. 297, Nolanfort, AR 84716-4096",
            "License Number": "919476328"
        },
        {
            "Number Plate": "'N74AH1413",
            "Name": "Turner Rogahn",
            "Address": "810 Koch Circles, Camyllechester, OK 23725",
            "License Number": "O142373873"
        },
        {
            "Number Plate": "“ALOTBRBOS5",
            "Name": "Susanna Morissette",
            "Address": "1210 Kessler Way, New Eulahport, HI 76635",
            "License Number": "H25316843"
        },
        {
            "Number Plate": "<< ——<‘i—ts—\r\n\r\nKLG10A2555",
            "Name": "Ariane Terry",
            "Address": "4986 Felicia Crescent, North Darwinmouth, CT 19330-3473",
            "License Number": "675562747"
        },
        {
            "Number Plate": "MH 2OBN 3525,",
            "Name": "Darien Brekke",
            "Address": "23512 Friesen Ridges Apt. 462, Raquelburgh, MI 42183",
            "License Number": "G 869 591 210 718"
        },
        {
            "Number Plate": "MH 20 EE 0943",
            "Name": "Frances McClure",
            "Address": "7022 Howe Rest, Harveyshire, SD 63551",
            "License Number": "96733303"
        },
        {
            "Number Plate": "Ne  GQG LS",
            "Name": "Arvid Dach",
            "Address": "65451 Jerrod Plains, Sawaynton, FL 93978",
            "License Number": "N281-012-28-363-0"
        },
        {
            "Number Plate": "—  } }—\r\n\r\nKL 1267531",
            "Name": "Leone Lakin",
            "Address": "621 Jacobson Ferry Apt. 759, North Kylaville, IN 60556",
            "License Number": "3527-61-8923"
        },
        {
            "Number Plate": "KL 7 BZ 99",
            "Name": "Alice Moen",
            "Address": "164 Al Summit Apt. 158, Langoshfurt, KS 84750-3328",
            "License Number": "K69-55-9539"
        },
        {
            "Number Plate": "KA226-",
            "Name": "Nelson Cummings",
            "Address": "6142 Albert Mountains Suite 471, Port Joanyhaven, VT 85169",
            "License Number": "91077935"
        },
        {
            "Number Plate": "L54 H 369",
            "Name": "Hans Hills",
            "Address": "69247 Maida Route, Lake Alvenaland, SC 22097-2403",
            "License Number": "274822255"
        },
        {
            "Number Plate": "~MH44EU3498",
            "Name": "Estella Runolfsdottir",
            "Address": "65413 Amely Stravenue Suite 915, Lake Gerson, OK 60523-7122",
            "License Number": "H317771134"
        },
        {
            "Number Plate": "MHGSBS 7778,",
            "Name": "Elizabeth Stamm",
            "Address": "777 Darrick Falls, New Pedro, NY 49894-2703",
            "License Number": "910 734 730"
        },
        {
            "Number Plate": "KL GON 5344",
            "Name": "Houston Rice",
            "Address": "9706 Alek Court Apt. 576, New Theresia, WV 48602-9356",
            "License Number": "1478758"
        },
        {
            "Number Plate": "PBOB CX 2959",
            "Name": "Oceane Bins",
            "Address": "51923 Goyette Corners Apt. 296, Runolfsdottirland, IL 06810-7640",
            "License Number": "K117-3104-0507"
        },
        {
            "Number Plate": "MH 01 BU5207",
            "Name": "Ervin Kunze",
            "Address": "2250 Jedediah Field Apt. 464, Ricetown, MN 35717-0646",
            "License Number": "X313788095814"
        },
        {
            "Number Plate": "HR 26 CT 6702",
            "Name": "Carmine Buckridge",
            "Address": "859 Sandrine Village, Miltonshire, DE 11038-5772",
            "License Number": "9227756"
        },
        {
            "Number Plate": "WOB eNP 3GG)",
            "Name": "Danny Kuhn",
            "Address": "36248 Beier Plains Apt. 686, West Marciaburgh, VA 79615-1586",
            "License Number": "192-49-5190"
        },
        {
            "Number Plate": "DAN 54P",
            "Name": "Deon Brown",
            "Address": "6063 Adrien Points Apt. 124, Idaport, KY 82038-3155",
            "License Number": "O41-834-240"
        },
        {
            "Number Plate": "KL34.B 4006",
            "Name": "Shayna Bailey",
            "Address": "31583 Green Bridge, Port Lenoreland, PA 99636-4101",
            "License Number": "26 656 448"
        },
        {
            "Number Plate": "UP 14CP 6748",
            "Name": "Percival Bailey",
            "Address": "2161 Abshire Land Suite 796, North Marjolaine, NV 01485",
            "License Number": "2682984418"
        },
        {
            "Number Plate": "05 Jp\r\n\r\n3759",
            "Name": "Raheem Kiehn",
            "Address": "2584 Schinner Pass Suite 896, Carterville, NV 77417",
            "License Number": "1840188584"
        },
        {
            "Number Plate": "\\N07BY5200)",
            "Name": "Lula Goyette",
            "Address": "300 Chyna Hills, Lake Dejuan, MS 57234-6655",
            "License Number": "389370042"
        },
        {
            "Number Plate": "MH 14 TCF 459",
            "Name": "Neva Barrows",
            "Address": "122 Harris Harbors, Willmsland, GA 02918",
            "License Number": "373927900"
        },
        {
            "Number Plate": "KA 21\r\n\r\nM5519.",
            "Name": "Murphy Nikolaus",
            "Address": "559 Kerluke Dam, Quigleymouth, IN 87638",
            "License Number": "3235-92-0872"
        },
        {
            "Number Plate": "’\r\n\r\nKL 16 J 3636.",
            "Name": "Patricia Schroeder",
            "Address": "31163 Morton Manors Suite 817, Port Kolbystad, WV 90056",
            "License Number": "4071912"
        },
        {
            "Number Plate": "MH 20 EE 7601",
            "Name": "Garret White",
            "Address": "12267 Anderson Meadows Apt. 374, Lake Modesto, MD 34643-1893",
            "License Number": "B-694-289-485-742"
        },
        {
            "Number Plate": "MH 20 EE 7598)",
            "Name": "Jarret Bartell",
            "Address": "389 Haag Avenue Apt. 461, East Lillianview, MT 17620",
            "License Number": "4.97199E+12"
        },
        {
            "Number Plate": "W\r\n\r\nPp Bo\r\n\r\n2 6786",
            "Name": "Guiseppe Beer",
            "Address": "94478 Johnson Green, Arielberg, CT 50302",
            "License Number": "926115301"
        },
        {
            "Number Plate": "‘GoTZP00",
            "Name": "Era Vandervort",
            "Address": "956 Amparo Turnpike, Hendersonbury, WY 56618",
            "License Number": "432792-352"
        },
        {
            "Number Plate": "KLO7BF5000",
            "Name": "Malachi Grant",
            "Address": "662 Bogan Orchard, Port Mateoton, DE 44758",
            "License Number": "5321323"
        },
        {
            "Number Plate": "KL 13 AA 6340)",
            "Name": "Madelyn Muller",
            "Address": "5947 Karlie Lodge Apt. 777, Lake Mariam, TN 67277-7835",
            "License Number": "227441210"
        },
        {
            "Number Plate": "~HR26DK6475",
            "Name": "Dewitt McLaughlin",
            "Address": "600 Kirk Islands, West Soledad, VA 84830",
            "License Number": "112-63-7039"
        },
        {
            "Number Plate": "~MHO4DW8351",
            "Name": "Cruz Bechtelar",
            "Address": "57746 Salvatore Green Apt. 821, Laurianeview, OR 04322-8041",
            "License Number": "48400148"
        },
        {
            "Number Plate": "KLOSAK 3300",
            "Name": "Kathryne Langosh",
            "Address": "9379 Schmeler Trafficway Suite 465, Port Lavern, VT 44391",
            "License Number": "45040655"
        },
        {
            "Number Plate": "TN52U 1580",
            "Name": "Jaylon Russel",
            "Address": "981 Melissa Meadow Suite 732, West Alessandraview, TX 90377",
            "License Number": "31523195"
        },
        {
            "Number Plate": "DL3CAY2231-",
            "Name": "Ethyl Williamson",
            "Address": "66656 Corkery Burgs Suite 435, Oberbrunnerville, WY 63173-2090",
            "License Number": "531408-024\r\n"
        },
        {
            "Number Plate": "KL 10 AV 6633",
            "Name": "Ressie Hammes",
            "Address": "39024 Kovacek Mountain, Earnestineland, GA 85605-8973",
            "License Number": "851679155"
        },
        {
            "Number Plate": "5 HKL 48H 9383",
            "Name": "Milton Carter",
            "Address": "586 Kuhic Mews, Malcolmfort, NM 37170",
            "License Number": "404390582"
        },
        {
            "Number Plate": "MH 20 EE 7598",
            "Name": "Sammy Hudson",
            "Address": "87819 Labadie Trail, North Rosalind, MO 24546",
            "License Number": "674863717"
        },
        {
            "Number Plate": "D\r\n\r\nL7S\r\n\r\n\"BS6930",
            "Name": "Holden Bernhard",
            "Address": "10568 Harris Terrace Suite 601, Ceceliaburgh, ND 16790",
            "License Number": "FJH-64-5118"
        },
        {
            "Number Plate": " = MHO1NE8O17",
            "Name": "Neha Kuhic",
            "Address": "80296 Gertrude Turnpike Apt. 996, New Angie, NY 78363-4954",
            "License Number": "430 047 344"
        },
        {
            "Number Plate": "TN\r\n\r\nj0158",
            "Name": "Alba Crist",
            "Address": "661 Jayde Branch, East Shanelview, WA 34784",
            "License Number": "CJRMUDX99428"
        },
        {
            "Number Plate": "el 20754",
            "Name": "Bernadine Green",
            "Address": "3143 Ankunding Canyon Apt. 804, West Citlalli, KY 81308-1421",
            "License Number": "Y64-547-027"
        },
        {
            "Number Plate": "HR26 BP3543",
            "Name": "Soledad Muller",
            "Address": "55355 Raleigh Walk Apt. 771, Framishire, OK 36980",
            "License Number": "C064990015"
        },
        {
            "Number Plate": "DL8Cx 4850",
            "Name": "Tyrell Berge",
            "Address": "48274 Mohr River, Lake Bertha, NE 40437-9874",
            "License Number": "Y60798386"
        },
        {
            "Number Plate": "QA 7222",
            "Name": "Adolf Johnson",
            "Address": "9804 Mafalda Crossing Suite 556, Port Genoveva, WV 35544",
            "License Number": "5133180"
        },
        {
            "Number Plate": "-DZI7 YXR",
            "Name": "Audreanne Ullrich",
            "Address": "197 Lynn Estates Suite 632, Whiteville, IN 66656",
            "License Number": "1158-81-9526"
        },
        {
            "Number Plate": "MH 01 BU5207\r\n\r\n——",
            "Name": "Maximus Wilderman",
            "Address": "504 Nolan Valley Apt. 784, Elzatown, MT 03861-5138",
            "License Number": "1.01674E+12"
        },
        {
            "Number Plate": "UPIGTC1366",
            "Name": "Nico Denesik",
            "Address": "3582 Casper Square Apt. 493, Hammesside, FL 51708",
            "License Number": "V466-984-59-620-1"
        },
        {
            "Number Plate": "OATMAK",
            "Name": "Ashley Thompson",
            "Address": "304 Heber Lock, Alexandriastad, SC 09218",
            "License Number": "158971728"
        },
        {
            "Number Plate": "CZI7 |",
            "Name": "Sonny Casper",
            "Address": "832 Arnulfo Gardens Suite 144, Flossieland, SD 20895-8831",
            "License Number": "4982367"
        },
        {
            "Number Plate": "\" MH15BD8877,",
            "Name": "Gerda Collins",
            "Address": "80468 Colt Passage Apt. 917, Gusikowskiside, MD 34580",
            "License Number": "G-217-365-842-004"
        },
        {
            "Number Plate": "MHO1NE8O17",
            "Name": "Johnny Prohaska",
            "Address": "28681 Padberg Loaf Apt. 786, Annabelberg, WA 86738",
            "License Number": "HSBXTHN44047"
        },
        {
            "Number Plate": "DL7C N 5617)",
            "Name": "Deon Sipes",
            "Address": "860 Dickinson Trace Apt. 520, Bonniestad, AK 11493",
            "License Number": "7882499"
        },
        {
            "Number Plate": "KL 49H\r\n\r\n/5270.\r\n ",
            "Name": "Cleta Frami",
            "Address": "6950 Candice Summit Apt. 987, West Mateoburgh, CT 35840-6035",
            "License Number": "701583605"
        },
        {
            "Number Plate": "GBI8 TCE",
            "Name": "Laverne Buckridge",
            "Address": "16019 Greenfelder Branch Suite 400, Runtestad, HI 82645-5096",
            "License Number": "H67904865"
        },
        {
            "Number Plate": "use 4",
            "Name": "Emory Crist",
            "Address": "699 Brielle Street, North Greysonberg, SD 96953-9014",
            "License Number": "56818884"
        },
        {
            "Number Plate": "| JPK 6546.",
            "Name": "Jackeline Christiansen",
            "Address": "530 Dave Viaduct, Javonborough, FL 21581-2624",
            "License Number": "L320-385-53-673-1"
        },
        {
            "Number Plate": "Puta 8303",
            "Name": "Jessica Buckridge",
            "Address": "92340 Winona Prairie, New Bernieceland, ND 74495",
            "License Number": "JEI-89-0028"
        },
        {
            "Number Plate": "VIZ LAF",
            "Name": "Carroll Cummings",
            "Address": "38056 Ethyl Meadows, Lake Dwightmouth, WV 71185-4336",
            "License Number": "5642324"
        },
        {
            "Number Plate": "NOTACOP",
            "Name": "Kylie Little",
            "Address": "75169 Armani Courts Suite 645, Lloydstad, DE 51674-3489",
            "License Number": "3292494"
        },
        {
            "Number Plate": "OMPLATE.COM",
            "Name": "Emilia Osinski",
            "Address": "19171 Schumm Street Apt. 833, Port Verner, NM 84476",
            "License Number": "555687249"
        },
        {
            "Number Plate": "<< ——<‘i—ts—\r\n\r\nKLG10A2555\r\n ",
            "Name": "Myrtle Heller",
            "Address": "87584 Kristina Lodge Suite 154, East Hollymouth, IN 75465",
            "License Number": "9076-37-7325"
        },
        {
            "Number Plate": "VX54FVL",
            "Name": "Jonas Collins",
            "Address": "647 Antwon Squares Suite 379, Port Phyllis, SD 68662",
            "License Number": "42791472"
        },
        {
            "Number Plate": "SKIP GAS;",
            "Name": "Dalton Glover",
            "Address": "3214 Little Roads Apt. 275, Gisselleside, ID 43490",
            "License Number": "TC857502P"
        },
        {
            "Number Plate": "GOOGLE",
            "Name": "Maximo Johns",
            "Address": "5635 Johanna Walks, Kertzmannfort, IL 22575",
            "License Number": "W826-6279-5840"
        },
        {
            "Number Plate": "BKTP: 665",
            "Name": "Mariah Mraz",
            "Address": "170 Dagmar Hills, Steveville, SD 70777",
            "License Number": "57596559"
        },
        {
            "Number Plate": "bo eeNesTOCK meDsMA",
            "Name": "Imogene Berge",
            "Address": "319 Mohammed Union Suite 254, Legroshaven, WI 14762-7299",
            "License Number": "X9545457112322"
        },
        {
            "Number Plate": "CHO1ANOOOT",
            "Name": "Emery Wisoky",
            "Address": "203 Cathy Squares, West Kaleyland, AZ 72818-3695",
            "License Number": "B50782797"
        },
        {
            "Number Plate": "TN21BC 6285",
            "Name": "Thaddeus Hayes",
            "Address": "24238 Zoila Circle, Lake Ova, AL 62627",
            "License Number": "5801071"
        },
        {
            "Number Plate": "BY 136",
            "Name": "Rasheed Keeling",
            "Address": "168 Leffler Mountains, Emardberg, RI 35596-9963",
            "License Number": "5546623"
        },
        {
            "Number Plate": "| MHI 9239-",
            "Name": "Eudora Schumm",
            "Address": "9582 Larkin Lake Suite 161, Langoshshire, AR 02554-9864",
            "License Number": "906608755"
        },
        {
            "Number Plate": "HR26 AZ 5927",
            "Name": "Carmelo Lowe",
            "Address": "27063 Noemy Ville Suite 879, Ignatiusport, DE 20361-2760",
            "License Number": "1968350"
        },
        {
            "Number Plate": "“MH15BD8877,",
            "Name": "Rene Blick",
            "Address": "61581 Considine Squares, Vickyport, FL 04457-7803",
            "License Number": "G782-841-73-091-0"
        },
        {
            "Number Plate": "BKWL 324",
            "Name": "Ayla Sauer",
            "Address": "411 Halvorson Vista Apt. 942, Gaylordton, ID 73643",
            "License Number": "UC131335T"
        },
        {
            "Number Plate": "| YNTZDBE |",
            "Name": "Chadrick Windler",
            "Address": "765 Everardo Gardens Suite 229, North Lynn, MO 75385",
            "License Number": "789442939"
        },
        {
            "Number Plate": "MH 12 NE S822",
            "Name": "Cecile Bode",
            "Address": "798 Kelton Junction, West Arloville, CO 03233",
            "License Number": "00-433-0476"
        },
        {
            "Number Plate": "~G600D >",
            "Name": "Bridget Kris",
            "Address": "272 Abernathy Wells Suite 031, East Florencio, CO 65786",
            "License Number": "68-102-5485"
        },
        {
            "Number Plate": "CHIO OSE",
            "Name": "Shyann Hammes",
            "Address": "5901 Elsa Parks Suite 768, Lake Orieville, CO 27290",
            "License Number": "46-055-5577"
        },
        {
            "Number Plate": "MK-35-32",
            "Name": "Orlo Kassulke",
            "Address": "6214 Sunny Green, South Issac, MD 15708",
            "License Number": "Q-144-437-188-546"
        },
        {
            "Number Plate": "SLISTLE",
            "Name": "Alexys Stiedemann",
            "Address": "73306 Burnice Brook Apt. 649, East Forest, TN 02301-9403",
            "License Number": "96397702"
        },
        {
            "Number Plate": "AFR-2011",
            "Name": "Cayla Mueller\r\n",
            "Address": "6736 Corine Key, Schmidtside, MS 66856-5373",
            "License Number": "639871216"
        },
        {
            "Number Plate": "HR 26 BU 0380",
            "Name": "Luisa Simonis",
            "Address": "86031 Florian Pass Suite 067, West Kaciport, WY 80856",
            "License Number": "596309-202"
        },
        {
            "Number Plate": "KL 65H 43982)",
            "Name": "Shayne Heaney",
            "Address": "4476 Camylle Locks, Winonafurt, OK 34780",
            "License Number": "B801833674"
        },
        {
            "Number Plate": "Were",
            "Name": "Pablo Gerhold\r\n",
            "Address": "7371 Paula Lodge, Ashlynnside, TN 44665-9450",
            "License Number": "947108735"
        },
        {
            "Number Plate": "Hie eg",
            "Name": "Chester Labadie\r\n",
            "Address": "6884 Neva Valleys, New Amariton, AR 76117-4988",
            "License Number": "998442041"
        },
        {
            "Number Plate": "rit 2009563]",
            "Name": "Rachelle Baumbach\r\n",
            "Address": "8169 Roman Trail, West Chaz, LA 06382",
            "License Number": "1869051"
        },
        {
            "Number Plate": "MH15BD8877,",
            "Name": "Landen Reichert\r\n",
            "Address": "931 Rogahn Underpass, Kiehnmouth, OR 50772",
            "License Number": "540117780"
        },
        {
            "Number Plate": "} }—\r\n\r\nKL 1267531\r\n ",
            "Name": "Pietro Leffler\r\n",
            "Address": "14942 Murray Estates, Lake Noahberg, RI 89299-1377\r\n",
            "License Number": "893750"
        }
    ]

# %%
rec = collection.insert_many(list_of_records)
